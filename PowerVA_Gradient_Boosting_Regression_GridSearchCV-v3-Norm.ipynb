# %%
#Data analysis and manipulation tool
import pandas as pd
#Google Drive
from google.colab import drive

# %%
#Mount Google Drive to Google Colab
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
#Verify mount is correct
# !ls -l gdrive/MyDrive/Colab\ Notebooks/PowerVA/csv
# Out:
# total 1026
# -rw------- 1 root root 514402 Jul 23 13:27 ALL-MULT-15-07-23-19-07-23.txt
# -rw------- 1 root root 535300 Jun 21 16:12 ALL-MULT.txt

# %%
#The "read_csv" method allows us to read a CSV
data_mult = pd.read_csv("gdrive/MyDrive/Colab Notebooks/PowerVA/csv/ALL-MULT-15-07-23-19-07-23.txt", header = None)
#Cov = pd.read_csv("path/to/file.txt", sep='\t', header=None)
data_mult.columns = ["ID", "Temperature", "Humidity", "UV","Voltage", "Current", "Illuminance", "ClientIP","SensorID", "DateTime"]

# %%
#Show information about dataset
data_mult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5801 entries, 0 to 5800
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           5801 non-null   int64
#  1   Temperature  5801 non-null   float64
#  2   Humidity     5801 non-null   float64
#  3   UV           5801 non-null   float64
#  4   Voltage      5801 non-null   float64
#  5   Current      5801 non-null   float64
#  6   Illuminance  5801 non-null   float64
#  7   ClientIP     5801 non-null   object
#  8   SensorID     5801 non-null   object
#  9   DateTime     5801 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 453.3+ KB

# %%
#Show first rows of dataset
data_mult.head()
# Out:
#        ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 0  359002         37.1      16.8  5.43    22.02     3.10      1011.75
# 1  359003         36.6      16.2  5.43    22.11     3.09      1012.30
# 2  359004         36.1      16.6  5.43    22.09     3.10      1011.85
# 3  359005         37.1      16.7  5.28    22.09     3.07      1011.75
# 4  359006         37.4      15.4  5.33    22.08     3.09      1011.80
#
#         ClientIP      SensorID             DateTime
# 0  179.7.224.186  PUN-JG167-S1  2023-07-15 13:15:18
# 1  179.7.224.186  PUN-JG167-S1  2023-07-15 13:16:18
# 2  179.7.224.186  PUN-JG167-S1  2023-07-15 13:17:18
# 3  179.7.224.186  PUN-JG167-S1  2023-07-15 13:18:18
# 4  179.7.224.186  PUN-JG167-S1  2023-07-15 13:19:19

# %%
#Show statistics of dataset
data_mult.describe()
# Out:
#                   ID  Temperature     Humidity           UV      Voltage  \
# count    5801.000000  5801.000000  5801.000000  5801.000000  5801.000000
# mean   361902.000000    15.236649    32.352767     1.541605     6.693475
# std      1674.748787    11.704084    12.099001     2.429351     9.293092
# min    359002.000000     0.600000    10.100000     0.000000     0.000000
# 25%    360452.000000     5.900000    22.700000     0.000000     0.000000
# 50%    361902.000000    11.000000    30.600000     0.050000     0.000000
# 75%    363352.000000    26.100000    42.400000     2.490000    19.640000
# max    364802.000000    43.800000    65.200000     8.410000    22.410000
#
#            Current  Illuminance
# count  5801.000000  5801.000000
# mean      1.089195   510.494251
# std       1.264111   462.771915
# min       0.120000    46.450000
# 25%       0.170000    52.750000
# 50%       0.200000   221.900000
# 75%       2.850000  1009.050000
# max       3.210000  1012.300000

# %%
#Show last rows of dataset
data_mult.tail()
# Out:
#           ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 5796  364798         28.2      18.3  1.22    12.11     1.83      1003.90
# 5797  364799         27.9      18.5  1.08    12.02     1.81      1004.25
# 5798  364800         28.2      18.5  1.12    11.89     1.81      1004.25
# 5799  364801         28.0      18.6  1.12    11.57     1.76      1004.30
# 5800  364802         28.0      18.5  1.22    11.25     1.71      1003.95
#
#            ClientIP      SensorID             DateTime
# 5796  179.7.224.186  PUN-JG167-S1  2023-07-19 15:46:34
# 5797  179.7.224.186  PUN-JG167-S1  2023-07-19 15:47:35
# 5798  179.7.224.186  PUN-JG167-S1  2023-07-19 15:48:35
# 5799  179.7.224.186  PUN-JG167-S1  2023-07-19 15:49:36
# 5800  179.7.224.186  PUN-JG167-S1  2023-07-19 15:50:36

# %%
#Show highest values of Electric Current
data_mult.loc[data_mult['Current'] > 3.19]
# Out:
#           ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 2690  361692         30.3      18.3  6.01    21.69     3.20      1011.40
# 2742  361744         33.0      16.8  7.97    21.80     3.20      1011.20
# 2743  361745         32.3      16.8  8.06    21.75     3.20      1011.20
# 2746  361748         33.1      16.8  7.82    21.84     3.21      1011.60
# 2747  361749         33.6      16.9  8.02    21.75     3.20      1011.50
# 2759  361761         35.2      15.7  8.11    21.79     3.20      1011.95
# 4116  363118         28.9      21.9  5.47    21.70     3.20      1011.25
# 5463  364465         16.3      31.6  2.69    21.35     3.21      1009.65
#
#            ClientIP      SensorID             DateTime
# 2690  179.7.224.186  PUN-JG167-S1  2023-07-17 10:29:09
# 2742  179.7.224.186  PUN-JG167-S1  2023-07-17 11:21:06
# 2743  179.7.224.186  PUN-JG167-S1  2023-07-17 11:22:06
# 2746  179.7.224.186  PUN-JG167-S1  2023-07-17 11:25:05
# ...

# %%
#Show highest values of Electric Potential
data_mult.loc[data_mult['Voltage'] > 22.3]
# Out:
#           ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 1394  360396         33.2      16.3  7.18    22.36     3.15      1011.85
# 1395  360397         31.4      17.5  7.04    22.39     3.14      1011.65
# 1397  360399         31.5      18.0  6.94    22.39     3.16      1011.80
# 1403  360405         33.2      16.9  6.50    22.33     3.15      1011.75
# 1404  360406         32.9      16.6  6.55    22.41     3.14      1011.35
# 1406  360408         32.6      16.8  6.50    22.33     3.15      1011.10
# 1431  360433         30.0      17.7  5.03    22.31     3.14      1011.30
# 1432  360434         29.9      18.0  5.08    22.31     3.16      1011.35
#
#            ClientIP      SensorID             DateTime
# 1394  179.7.224.186  PUN-JG167-S1  2023-07-16 12:39:50
# 1395  179.7.224.186  PUN-JG167-S1  2023-07-16 12:40:50
# 1397  179.7.224.186  PUN-JG167-S1  2023-07-16 12:42:50
# 1403  179.7.224.186  PUN-JG167-S1  2023-07-16 12:50:50
# ...

# %%
#Power is the multiplication of Electric Current and Electric Potential
data_mult['Power'] = data_mult['Current']*data_mult['Voltage']

# %%
#Show first rows of dataset with Power
data_mult.head()
# Out:
#        ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 0  359002         37.1      16.8  5.43    22.02     3.10      1011.75
# 1  359003         36.6      16.2  5.43    22.11     3.09      1012.30
# 2  359004         36.1      16.6  5.43    22.09     3.10      1011.85
# 3  359005         37.1      16.7  5.28    22.09     3.07      1011.75
# 4  359006         37.4      15.4  5.33    22.08     3.09      1011.80
#
#         ClientIP      SensorID             DateTime    Power
# 0  179.7.224.186  PUN-JG167-S1  2023-07-15 13:15:18  68.2620
# 1  179.7.224.186  PUN-JG167-S1  2023-07-15 13:16:18  68.3199
# 2  179.7.224.186  PUN-JG167-S1  2023-07-15 13:17:18  68.4790
# 3  179.7.224.186  PUN-JG167-S1  2023-07-15 13:18:18  67.8163
# 4  179.7.224.186  PUN-JG167-S1  2023-07-15 13:19:19  68.2272

# %%
#Show last rows of dataset with Power
data_mult.tail()
# Out:
#           ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 5796  364798         28.2      18.3  1.22    12.11     1.83      1003.90
# 5797  364799         27.9      18.5  1.08    12.02     1.81      1004.25
# 5798  364800         28.2      18.5  1.12    11.89     1.81      1004.25
# 5799  364801         28.0      18.6  1.12    11.57     1.76      1004.30
# 5800  364802         28.0      18.5  1.22    11.25     1.71      1003.95
#
#            ClientIP      SensorID             DateTime    Power
# 5796  179.7.224.186  PUN-JG167-S1  2023-07-19 15:46:34  22.1613
# 5797  179.7.224.186  PUN-JG167-S1  2023-07-19 15:47:35  21.7562
# 5798  179.7.224.186  PUN-JG167-S1  2023-07-19 15:48:35  21.5209
# 5799  179.7.224.186  PUN-JG167-S1  2023-07-19 15:49:36  20.3632
# 5800  179.7.224.186  PUN-JG167-S1  2023-07-19 15:50:36  19.2375

# %%
#Show sample of rows with Power
data_mult.sample(5)
# Out:
#           ID  Temperature  Humidity    UV  Voltage  Current  Illuminance  \
# 4590  363592         11.1      52.1  0.00     0.00     0.15        51.85
# 2938  361940         31.4      14.3  1.32     5.45     0.95       992.70
# 886   359888          1.7      33.3  0.00     0.00     0.15        52.55
# 4230  363232         34.7      16.1  7.14    21.68     3.13      1011.30
# 1081  360083          8.6      30.9  0.68     6.23     1.06       991.80
#
#            ClientIP      SensorID             DateTime    Power
# 4590  179.7.224.186  PUN-JG167-S1  2023-07-18 18:31:30   0.0000
# 2938  179.7.224.186  PUN-JG167-S1  2023-07-17 14:37:56   5.1775
# 886   179.7.224.186  PUN-JG167-S1  2023-07-16 04:03:46   0.0000
# 4230  179.7.224.186  PUN-JG167-S1  2023-07-18 12:20:29  67.8584
# 1081  179.7.224.186  PUN-JG167-S1  2023-07-16 07:18:46   6.6038

# %% [markdown]
# # Gradient Boosting Regression

# %%
#Tool for plotting
import matplotlib.pyplot as plt
#Wide variety of mathematical operations on arrays
import numpy as np
#Ensemble methods
from sklearn import ensemble
#Permutation importance for feature evaluation
from sklearn.inspection import permutation_importance
#Error metrics and Score metric
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
#Split arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
#Exhaustive search over specified parameter values for an estimator
from sklearn.model_selection import GridSearchCV
#Scale input vectors individually to unit norm (vector length)
from sklearn import preprocessing

# %%
#Select independent variables from the dependent variable
X = data_mult[["Temperature", "Humidity", "UV", "Illuminance"]]
y = data_mult[["Power"]]

# %%
#Show independent variables
X
# Out:
#       Temperature  Humidity    UV  Illuminance
# 0            37.1      16.8  5.43      1011.75
# 1            36.6      16.2  5.43      1012.30
# 2            36.1      16.6  5.43      1011.85
# 3            37.1      16.7  5.28      1011.75
# 4            37.4      15.4  5.33      1011.80
# ...           ...       ...   ...          ...
# 5796         28.2      18.3  1.22      1003.90
# 5797         27.9      18.5  1.08      1004.25
# 5798         28.2      18.5  1.12      1004.25
# 5799         28.0      18.6  1.12      1004.30
# 5800         28.0      18.5  1.22      1003.95
#
# [5801 rows x 4 columns]

# %%
#Show dependent variable
y
# Out:
#         Power
# 0     68.2620
# 1     68.3199
# 2     68.4790
# 3     67.8163
# 4     68.2272
# ...       ...
# 5796  22.1613
# 5797  21.7562
# 5798  21.5209
# 5799  20.3632
# 5800  19.2375
#
# [5801 rows x 1 columns]

# %%
#Scale independent variables input vectors individually to unit norm
X = preprocessing.normalize(X)

# %%
#Convert to dataframe and add coulmns names
X = pd.DataFrame(X)
X.columns = ["Temperature", "Humidity", "UV", "Illuminance"]

# %%
#Show independent variables
X
# Out:
#       Temperature  Humidity        UV  Illuminance
# 0        0.036639  0.016591  0.005363     0.999176
# 1        0.036127  0.015990  0.005360     0.999205
# 2        0.035649  0.016393  0.005362     0.999216
# 3        0.036639  0.016493  0.005214     0.999179
# 4        0.036934  0.015208  0.005264     0.999188
# ...           ...       ...       ...          ...
# 5796     0.028075  0.018219  0.001215     0.999439
# 5797     0.027766  0.018411  0.001075     0.999444
# 5798     0.028065  0.018411  0.001115     0.999436
# 5799     0.027864  0.018510  0.001115     0.999440
# 5800     0.027874  0.018417  0.001215     0.999441
#
# [5801 rows x 4 columns]

# %%
#Show dependent variable
y
# Out:
#         Power
# 0     68.2620
# 1     68.3199
# 2     68.4790
# 3     67.8163
# 4     68.2272
# ...       ...
# 5796  22.1613
# 5797  21.7562
# 5798  21.5209
# 5799  20.3632
# 5800  19.2375
#
# [5801 rows x 1 columns]

# %%
#Split dataset for train and test subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
#Verify number of elements in the split
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4640, 4)
# (4640, 1)
# (1161, 4)
# (1161, 1)

# %%
#Set parameters like the number of estimators and learning rate
params = {'n_estimators': 100,
          'max_depth': 10,
          'min_samples_split': 5,
          'learning_rate': 0.1,
          'loss': 'squared_error'}

# %%
#Apply parameters for Gradient Boosting Regressor
reg = ensemble.GradientBoostingRegressor(**params)
#Fit using training data
reg.fit(X_train, y_train)
#Predict using independent test variables
reg_predict = reg.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Mean Squared Error
mse = mean_squared_error(y_test, reg_predict)
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 5.3750

# %%
#Root Mean Squared Error
rmse = np.sqrt(mean_squared_error(y_test, reg_predict))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 2.318404

# %%
#Mean Absolute Error
mae = mean_absolute_error(y_test, reg_predict)
print("MAE: %f" % (mae))
# Out:
# MAE: 0.573647

# %%
#Mean Absolute Error Percentage
mape = mean_absolute_percentage_error(y_test, reg_predict)
print("MAPE: %f" % (mape))
# Out:
# MAPE: 2222351157636.784180

# %%
#Score for training
reg_score_train = reg.score(X_train, y_train)
print(reg_score_train)
# Out:
# 0.9999932522115549

# %%
#Score for test
reg_score_test = reg.score(X_test, y_test)
print(reg_score_test)
# Out:
# 0.9935098551990857

# %%
#Score for test using R2 score function
reg_r2_score = r2_score(y_test, reg_predict)
print(reg_r2_score)
# Out:
# 0.9935098551990857

# %%
#Show Original vs Predicted data
x_ax = range(len(y_test))
plt.figure(figsize=(24,10))
plt.title("Original vs Predicted", fontsize = 16)
plt.ylabel("Power", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.plot(x_ax, y_test, lw=0.8, color="blue", label="original")
plt.plot(x_ax, reg_predict, lw=0.8, color="red", label="predicted")
plt.legend(fontsize = 16)
plt.show()

# %%
#Show Original vs Predicted data
x_ax = range(0,150)
plt.figure(figsize=(24,10))
plt.title("Original vs Predicted", fontsize = 16)
plt.ylabel("Power", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.plot(x_ax, y_test[0:150], lw=1.8, color="blue", label="original")
plt.plot(x_ax, reg_predict[0:150], lw=1.8, color="red", label="predicted")
plt.legend(fontsize = 16)
plt.show()

# %% [markdown]
# #GridSearchCV

# %%
#Show predictions
print(reg_predict)
print(len(reg_predict))
print(reg_predict.shape)
# Out:
# [9.28386393e-04 9.28895813e-04 9.28895813e-04 ... 9.28895813e-04
#  9.28386393e-04 6.35102766e+01]
# 1161
# (1161,)

# %%
#Show real test data
print(y_test)
print(len(y_test))
print(y_test.shape)
# Out:
#         Power
# 803    0.0000
# 4770   0.0000
# 2030   0.0000
# 1399  69.4200
# 1123   0.6200
# ...       ...
# 812    0.0000
# 1612   0.5616
# 4678   0.0000
# 3845   0.0000
# 4348  63.5391
#
# [1161 rows x 1 columns]
# 1161
# (1161, 1)

# %%
#Verifiy training data
print(X_train.shape[0])
print(X_train.shape[1])
# Out:
# 4640
# 4

# %%
#Set hyperparameters
# %%time

params = {'n_estimators': [100,150,200,250],
          'max_depth': [4,8,12],
          'min_samples_split': [10,15,20],
          'learning_rate': [0.025,0.05,0.1,0.15],
          'loss': ['squared_error', 'absolute_error', 'huber', 'quantile']}
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 11 µs

# %%
#Use GridSearchCV to find the best fit
grad_boost_regressor_grid = GridSearchCV(ensemble.GradientBoostingRegressor(random_state=123), param_grid =params, cv=5, n_jobs=-1, verbose=1)
grad_boost_regressor_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=123),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.025, 0.05, 0.1, 0.15],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'max_depth': [4, 8, 12],
#                          'min_samples_split': [10, 15, 20],
#                          'n_estimators': [100, 150, 200, 250]},
#              verbose=1)

# %%
#Show the best score and model
print('Train R^2 Score : %.3f'%grad_boost_regressor_grid.best_estimator_.score(X_train, y_train))
print('Test R^2 Score : %.3f'%grad_boost_regressor_grid.best_estimator_.score(X_test, y_test))
print('Best R^2 Score Through Grid Search : %.3f'%grad_boost_regressor_grid.best_score_)
print('Best Parameters : ',grad_boost_regressor_grid.best_params_)
# Out:
# Train R^2 Score : 1.000
# Test R^2 Score : 0.994
# Best R^2 Score Through Grid Search : 0.990
# Best Parameters :  {'learning_rate': 0.15, 'loss': 'squared_error', 'max_depth': 8, 'min_samples_split': 20, 'n_estimators': 100}

# %%
#Show the first results from the Cross Validation Table
cross_val_results = pd.DataFrame(grad_boost_regressor_grid.cv_results_)
print('Number of Various Combinations of Parameters Tried : %d'%len(cross_val_results))

cross_val_results.head()
# Out:
# Number of Various Combinations of Parameters Tried : 576
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.462284      0.465048         0.008796        0.002939
# 1       1.590310      0.032477         0.008656        0.000290
# 2       2.458073      0.542867         0.014137        0.006275
# 3       3.338254      0.964473         0.010756        0.000312
# 4       1.041353      0.013984         0.007175        0.000190
#
#   param_learning_rate     param_loss param_max_depth param_min_samples_split  \
# 0               0.025  squared_error               4                      10
# 1               0.025  squared_error               4                      10
# 2               0.025  squared_error               4                      10
# 3               0.025  squared_error               4                      10
# 4               0.025  squared_error               4                      15
#
# ...

# %% [markdown]
# #Evaluation of the best model

# %%
#Predict using test data then compare with real data (y_test)
grad_boost_regressor_grid_predict_train = grad_boost_regressor_grid.predict(X_train)
grad_boost_regressor_grid_predict = grad_boost_regressor_grid.predict(X_test)

# %% [markdown]
# Veamos también el error cuadrático medio en los datos de prueba, la raíz del error cuadrático medio en los datos de prueba y el puntaje (score) de entrenamiento y pruebas.

# %%
mse = mean_squared_error(y_test, grad_boost_regressor_grid_predict)
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 4.7594

# %%
rmse = np.sqrt(mean_squared_error(y_test, grad_boost_regressor_grid_predict))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 2.181610

# %%
mae = mean_absolute_error(y_test, grad_boost_regressor_grid_predict)
print("MAE: %f" % (mae))
# Out:
# MAE: 0.624390

# %%
mape = mean_absolute_percentage_error(y_test, grad_boost_regressor_grid_predict)
print("MAPE: %f" % (mape))
# Out:
# MAPE: 9882416209549.171875

# %%
reg_score_train = grad_boost_regressor_grid.score(X_train, y_train)
print(reg_score_train)
# Out:
# 0.9998822645186113

# %%
reg_score_test = grad_boost_regressor_grid.score(X_test, y_test)
print(reg_score_test)
# Out:
# 0.9942531460749789

# %%
reg_r2_score = r2_score(y_test, grad_boost_regressor_grid_predict)
print(reg_r2_score)
# Out:
# 0.9942531460749789

# %%
#Show Original vs Predicted data
x_ax = range(len(y_test))
plt.figure(figsize=(24,10))
plt.title("Original vs Predicted", fontsize = 16)
plt.ylabel("Power", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.plot(x_ax, y_test, lw=0.8, color="blue", label="original")
plt.plot(x_ax, grad_boost_regressor_grid_predict, lw=0.8, color="red", label="predicted")
plt.legend(fontsize = 16)
plt.show()

# %%
#Show Original vs Predicted data
x_ax = range(0,150)
plt.figure(figsize=(24,10))
plt.title("Original vs Predicted", fontsize = 16)
plt.ylabel("Power", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.plot(x_ax, y_test[0:150], lw=1.8, color="blue", label="original")
plt.plot(x_ax, grad_boost_regressor_grid_predict[0:150], lw=1.8, color="red", label="predicted")
plt.legend(fontsize = 16)
plt.show()
